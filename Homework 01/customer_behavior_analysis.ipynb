# %%
# main library
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import re
import os

# %matplotlib inline

# %%
cust_df = pd.read_excel('Customer Behaviors (Responses).xlsx')
cust_df.head()
# Out:
#                 Timestamp  \
# 0 2021-01-09 10:07:27.365
# 1 2021-01-09 10:07:34.010
# 2 2021-01-09 10:07:35.902
# 3 2021-01-09 10:07:36.476
# 4 2021-01-09 10:07:41.965
#
#   คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารญี่ปุ่น]  \
# 0                                               สนใจ
# 1                                       สนใจอย่างมาก
# 2                                 สนใจอย่างมากที่สุด
# 3                                               สนใจ
# 4                                       สนใจอย่างมาก
#
#   คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารจึน]  \
# 0                                               สนใจ
# 1                                               เฉยๆ
# 2                                               เฉยๆ
# 3                                               เฉยๆ
# 4                                               สนใจ
#
#   คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารไทย]  \
# 0                                 สนใจอย่างมากที่สุด
# 1                                 สนใจอย่างมากที่สุด
# 2                                       สนใจอย่างมาก
# 3                                               เฉยๆ
# 4                                               สนใจ
#
#   คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารอีสาน]  \
# 0                                       สนใจอย่างมาก
# 1                                       สนใจอย่างมาก
# 2                                               สนใจ
# 3                                               เฉยๆ
# 4                                               สนใจ
#
#   คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [อาหารสุขภาพ]  \
# 0                                               สนใจ
# 1                                               สนใจ
# 2                                               เฉยๆ
# 3                                               สนใจ
# 4                                 สนใจอย่างมากที่สุด
#
#   คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [บุฟเฟต์]  \
# 0                                               สนใจ
# 1                                       สนใจอย่างมาก
# 2                                 สนใจอย่างมากที่สุด
# 3                                               สนใจ
# 4                                               เฉยๆ
#
#   คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ชาบูชาบู]  \
# 0                                               สนใจ
# 1                                 สนใจอย่างมากที่สุด
# 2                                 สนใจอย่างมากที่สุด
# 3                                               สนใจ
# 4                                               เฉยๆ
#
#   คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [ปิ้งย่าง]  \
# 0                                               สนใจ
# 1                                       สนใจอย่างมาก
# 2                                 สนใจอย่างมากที่สุด
# 3                                               สนใจ
# 4                                               เฉยๆ
#
#   คุณมีความสนใจในสิ่งเหล่านี้มากน้อยเพียงใด [เหล้าเบียร์]  ...  \
# 0                                 สนใจอย่างมากที่สุด       ...
# 1                                            ไม่สนใจ       ...
# 2                                    ไม่สนใจอย่างมาก       ...
# 3                              ไม่สนใจอย่างมากที่สุด       ...
# 4                                               เฉยๆ       ...
#
#   คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่่ยวกับเกมส์]  \
# 0                                       เดือนละครั้ง
# 1                                  เดือนละ 2-3 ครั้ง
# 2                                          แทบทุกวัน
# 3                                          แทบทุกวัน
# 4                                 แทบไม่ได้บริโภคเลย
#
#   คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการ review ร้านอาหาร]  \
# 0                                  เดือนละ 2-3 ครั้ง
# 1                                          แทบทุกวัน
# 2                                          แทบทุกวัน
# 3                                       เดือนละครั้ง
# 4                                       เดือนละครั้ง
#
#   คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการท่องเที่ยว]  \
# 0                                  เดือนละ 2-3 ครั้ง
# 1                                          แทบทุกวัน
# 2                                  เดือนละ 2-3 ครั้ง
# 3                                       เดือนละครั้ง
# 4                                  เดือนละ 2-3 ครั้ง
#
#   คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการแต่งบ้าน]  \
# 0                                  เดือนละ 2-3 ครั้ง
# 1                                     อาทิตย์ละครั้ง
# 2                                  เดือนละ 2-3 ครั้ง
# 3                                 แทบไม่ได้บริโภคเลย
# 4                                       เดือนละครั้ง
#
#   คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการโทรทัศน์]  \
# 0                                  เดือนละ 2-3 ครั้ง
# 1                                     หลายเดือนครั้ง
# 2                                  เดือนละ 2-3 ครั้ง
# 3                                 แทบไม่ได้บริโภคเลย
# 4                                 แทบไม่ได้บริโภคเลย
#
#   คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับละคร]  \
# 0                                  เดือนละ 2-3 ครั้ง
# 1                                     หลายเดือนครั้ง
# 2                                     หลายเดือนครั้ง
# 3                                 แทบไม่ได้บริโภคเลย
# 4                                 แทบไม่ได้บริโภคเลย
#
#   คุณบริโภคสิ่งเหล่านี้บ่อยขนาดไหน [Content เกี่ยวกับการเมือง]  \
# 0                                          แทบทุกวัน
# 1                                     อาทิตย์ละครั้ง
# 2                                          แทบทุกวัน
# 3                                  เดือนละ 2-3 ครั้ง
# 4                                  เดือนละ 2-3 ครั้ง
#
#   นอกเหนือจากรายการดังกล่าวแล้ว คุณมีความสนใจในเรื่องใดอีกบ้าง  \
# 0                                   กีฬา UFC, Soccer
# 1                         กีฬา สัตว์เลี้ยง เทคโนโลยี
# 2                                                  -
# 3                                   โหราศาสตร์,ดูดวง
# 4                                        สัตว์เลี้ยง
#
#   คุณเกิดวันที่เท่าไหร่   เพศ
# 0   1988-09-19 00:00:00   ชาย
# 1   2536-08-10 00:00:00  หญิง
# 2   1993-11-07 00:00:00   ชาย
# 3   1994-04-14 00:00:00   ชาย
# 4   1995-04-19 00:00:00  หญิง
#
# [5 rows x 64 columns]

# %%
print('Data Dimention :',cust_df.shape)
# Out:
# Data Dimention : (63, 64)

# %% [markdown]
# # Prepare data

# %%
import re

# cleansing column name
for col in cust_df.columns:
    if col.startswith("คุณมีความสนใจ"):
        text_in_brackket = re.match(r"[^[]*\[([^]]*)\]", col).groups()[0]
        new_col_name = 'สนใจ '+text_in_brackket
        cust_df.rename(columns={col:new_col_name},inplace=True)
    elif col.startswith("คุณบริโภค"):
        text_in_brackket = re.match(r"[^[]*\[([^]]*)\]", col).groups()[0]
        new_col_name = 'บริโภค '+text_in_brackket
        cust_df.rename(columns={col:new_col_name},inplace=True)

for col in cust_df.columns:
    print(col)
# Out:
# Timestamp
# สนใจ อาหารญี่ปุ่น
# สนใจ อาหารจึน
# สนใจ อาหารไทย
# สนใจ อาหารอีสาน
# สนใจ อาหารสุขภาพ
# สนใจ บุฟเฟต์
# สนใจ ชาบูชาบู
# สนใจ ปิ้งย่าง
# สนใจ เหล้าเบียร์
# สนใจ เสื้อผ้าแฟชั่น
# สนใจ แต่งหน้า
# สนใจ skincare บำรุงผิว
# สนใจ การออกกำลังกาย
# สนใจ การเล่นเกมส์
# สนใจ การท่องเที่ยว
# สนใจ การอ่านหนังสือ
# สนใจ การอ่านบทความ Online
# สนใจ การเรียน e-learning
# สนใจ ดู Series
# สนใจ ดูหนัง
# สนใจ ดู Youtube
# สนใจ ดู Netflix
# สนใจ Content ด้านบันเทิง
# สนใจ Content เกี่่ยวกับเกมส์
# สนใจ Content เกี่ยวกับการ review ร้านอาหาร
# สนใจ Content เกี่ยวกับการท่องเที่ยว
# สนใจ Content เกี่ยวกับการแต่งบ้าน
# สนใจ Content เกี่ยวกับการโทรทัศน์
# สนใจ Content เกี่ยวกับละคร
# สนใจ Content เกี่ยวกับการเมือง
# บริโภค อาหารญี่ปุ่น
# บริโภค อาหารจึน
# บริโภค อาหารไทย
# บริโภค อาหารอีสาน
# บริโภค อาหารสุขภาพ
# บริโภค บุฟเฟต์
# บริโภค ชาบูชาบู
# บริโภค ปิ้งย่าง
# บริโภค เหล้าเบียร์
# บริโภค เสื้อผ้าแฟชั่น
# บริโภค แต่งหน้า
# บริโภค skincare บำรุงผิว
# บริโภค การออกกำลังกาย
# บริโภค การเล่นเกมส์
# บริโภค การท่องเที่ยว
# บริโภค การอ่านหนังสือ
# บริโภค การอ่านบทความ Online
# บริโภค การเรียน e-learning
# บริโภค ดู Series
# บริโภค ดูหนัง
# บริโภค ดู Youtube
# บริโภค ดู Netflix
# บริโภค Content ด้านบันเทิง
# บริโภค Content เกี่่ยวกับเกมส์
# บริโภค Content เกี่ยวกับการ review ร้านอาหาร
# บริโภค Content เกี่ยวกับการท่องเที่ยว
# บริโภค Content เกี่ยวกับการแต่งบ้าน
# บริโภค Content เกี่ยวกับการโทรทัศน์
# บริโภค Content เกี่ยวกับละคร
# บริโภค Content เกี่ยวกับการเมือง
# นอกเหนือจากรายการดังกล่าวแล้ว คุณมีความสนใจในเรื่องใดอีกบ้าง
# คุณเกิดวันที่เท่าไหร่
# เพศ

# %%
# แก้ไขข้อมูล พศ ให้เป็น คศ

from datetime import datetime, date 
from dateutil.relativedelta import relativedelta

d1 = datetime(2021, 3, 1)
# แปลงอายุที่กรอกเป็นปี พส.
cust_df.loc[cust_df['คุณเกิดวันที่เท่าไหร่']>d1, 'คุณเกิดวันที่เท่าไหร่'] = cust_df['คุณเกิดวันที่เท่าไหร่']-relativedelta(years=543)
cust_df.head(5)
# Out:
#                 Timestamp   สนใจ อาหารญี่ปุ่น สนใจ อาหารจึน  \
# 0 2021-01-09 10:07:27.365                สนใจ          สนใจ
# 1 2021-01-09 10:07:34.010        สนใจอย่างมาก          เฉยๆ
# 2 2021-01-09 10:07:35.902  สนใจอย่างมากที่สุด          เฉยๆ
# 3 2021-01-09 10:07:36.476                สนใจ          เฉยๆ
# 4 2021-01-09 10:07:41.965        สนใจอย่างมาก          สนใจ
#
#         สนใจ อาหารไทย สนใจ อาหารอีสาน    สนใจ อาหารสุขภาพ        สนใจ บุฟเฟต์  \
# 0  สนใจอย่างมากที่สุด    สนใจอย่างมาก                สนใจ                สนใจ
# 1  สนใจอย่างมากที่สุด    สนใจอย่างมาก                สนใจ        สนใจอย่างมาก
# 2        สนใจอย่างมาก            สนใจ                เฉยๆ  สนใจอย่างมากที่สุด
# 3                เฉยๆ            เฉยๆ                สนใจ                สนใจ
# 4                สนใจ            สนใจ  สนใจอย่างมากที่สุด                เฉยๆ
#
#         สนใจ ชาบูชาบู       สนใจ ปิ้งย่าง       สนใจ เหล้าเบียร์  ...  \
# 0                สนใจ                สนใจ     สนใจอย่างมากที่สุด  ...
# 1  สนใจอย่างมากที่สุด        สนใจอย่างมาก                ไม่สนใจ  ...
# 2  สนใจอย่างมากที่สุด  สนใจอย่างมากที่สุด        ไม่สนใจอย่างมาก  ...
# 3                สนใจ                สนใจ  ไม่สนใจอย่างมากที่สุด  ...
# 4                เฉยๆ                เฉยๆ                   เฉยๆ  ...
#
#   บริโภค Content เกี่่ยวกับเกมส์ บริโภค Content เกี่ยวกับการ review ร้านอาหาร  \
# 0                   เดือนละครั้ง                            เดือนละ 2-3 ครั้ง
# 1              เดือนละ 2-3 ครั้ง                                    แทบทุกวัน
# 2                      แทบทุกวัน                                    แทบทุกวัน
# 3                      แทบทุกวัน                                 เดือนละครั้ง
# 4             แทบไม่ได้บริโภคเลย                                 เดือนละครั้ง
#
#   บริโภค Content เกี่ยวกับการท่องเที่ยว บริโภค Content เกี่ยวกับการแต่งบ้าน  \
# 0                     เดือนละ 2-3 ครั้ง                   เดือนละ 2-3 ครั้ง
# 1                             แทบทุกวัน                      อาทิตย์ละครั้ง
# 2                     เดือนละ 2-3 ครั้ง                   เดือนละ 2-3 ครั้ง
# 3                          เดือนละครั้ง                  แทบไม่ได้บริโภคเลย
# 4                     เดือนละ 2-3 ครั้ง                        เดือนละครั้ง
#
#   บริโภค Content เกี่ยวกับการโทรทัศน์ บริโภค Content เกี่ยวกับละคร  \
# 0                   เดือนละ 2-3 ครั้ง            เดือนละ 2-3 ครั้ง
# 1                      หลายเดือนครั้ง               หลายเดือนครั้ง
# 2                   เดือนละ 2-3 ครั้ง               หลายเดือนครั้ง
# 3                  แทบไม่ได้บริโภคเลย           แทบไม่ได้บริโภคเลย
# 4                  แทบไม่ได้บริโภคเลย           แทบไม่ได้บริโภคเลย
#
#   บริโภค Content เกี่ยวกับการเมือง  \
# 0                        แทบทุกวัน
# 1                   อาทิตย์ละครั้ง
# 2                        แทบทุกวัน
# 3                เดือนละ 2-3 ครั้ง
# 4                เดือนละ 2-3 ครั้ง
#
#   นอกเหนือจากรายการดังกล่าวแล้ว คุณมีความสนใจในเรื่องใดอีกบ้าง  \
# 0                                   กีฬา UFC, Soccer
# 1                         กีฬา สัตว์เลี้ยง เทคโนโลยี
# 2                                                  -
# 3                                   โหราศาสตร์,ดูดวง
# 4                                        สัตว์เลี้ยง
#
#   คุณเกิดวันที่เท่าไหร่   เพศ
# 0   1988-09-19 00:00:00   ชาย
# 1   1993-08-10 00:00:00  หญิง
# 2   1993-11-07 00:00:00   ชาย
# 3   1994-04-14 00:00:00   ชาย
# 4   1995-04-19 00:00:00  หญิง
#
# [5 rows x 64 columns]

# %%
# calculate age 
def calculate_age(born):
#     born = datetime.strptime(born, "%d/%m/%Y").date()
    today = date.today()
    return today.year - born.year - ((today.month, today.day) < (born.month, born.day))

cust_df['อายุ'] = cust_df['คุณเกิดวันที่เท่าไหร่'].apply(calculate_age)
cust_df.head()
# Out:
#                 Timestamp   สนใจ อาหารญี่ปุ่น สนใจ อาหารจึน  \
# 0 2021-01-09 10:07:27.365                สนใจ          สนใจ
# 1 2021-01-09 10:07:34.010        สนใจอย่างมาก          เฉยๆ
# 2 2021-01-09 10:07:35.902  สนใจอย่างมากที่สุด          เฉยๆ
# 3 2021-01-09 10:07:36.476                สนใจ          เฉยๆ
# 4 2021-01-09 10:07:41.965        สนใจอย่างมาก          สนใจ
#
#         สนใจ อาหารไทย สนใจ อาหารอีสาน    สนใจ อาหารสุขภาพ        สนใจ บุฟเฟต์  \
# 0  สนใจอย่างมากที่สุด    สนใจอย่างมาก                สนใจ                สนใจ
# 1  สนใจอย่างมากที่สุด    สนใจอย่างมาก                สนใจ        สนใจอย่างมาก
# 2        สนใจอย่างมาก            สนใจ                เฉยๆ  สนใจอย่างมากที่สุด
# 3                เฉยๆ            เฉยๆ                สนใจ                สนใจ
# 4                สนใจ            สนใจ  สนใจอย่างมากที่สุด                เฉยๆ
#
#         สนใจ ชาบูชาบู       สนใจ ปิ้งย่าง       สนใจ เหล้าเบียร์  ...  \
# 0                สนใจ                สนใจ     สนใจอย่างมากที่สุด  ...
# 1  สนใจอย่างมากที่สุด        สนใจอย่างมาก                ไม่สนใจ  ...
# 2  สนใจอย่างมากที่สุด  สนใจอย่างมากที่สุด        ไม่สนใจอย่างมาก  ...
# 3                สนใจ                สนใจ  ไม่สนใจอย่างมากที่สุด  ...
# 4                เฉยๆ                เฉยๆ                   เฉยๆ  ...
#
#   บริโภค Content เกี่ยวกับการ review ร้านอาหาร  \
# 0                            เดือนละ 2-3 ครั้ง
# 1                                    แทบทุกวัน
# 2                                    แทบทุกวัน
# 3                                 เดือนละครั้ง
# 4                                 เดือนละครั้ง
#
#   บริโภค Content เกี่ยวกับการท่องเที่ยว บริโภค Content เกี่ยวกับการแต่งบ้าน  \
# 0                     เดือนละ 2-3 ครั้ง                   เดือนละ 2-3 ครั้ง
# 1                             แทบทุกวัน                      อาทิตย์ละครั้ง
# 2                     เดือนละ 2-3 ครั้ง                   เดือนละ 2-3 ครั้ง
# 3                          เดือนละครั้ง                  แทบไม่ได้บริโภคเลย
# 4                     เดือนละ 2-3 ครั้ง                        เดือนละครั้ง
#
#   บริโภค Content เกี่ยวกับการโทรทัศน์ บริโภค Content เกี่ยวกับละคร  \
# 0                   เดือนละ 2-3 ครั้ง            เดือนละ 2-3 ครั้ง
# 1                      หลายเดือนครั้ง               หลายเดือนครั้ง
# 2                   เดือนละ 2-3 ครั้ง               หลายเดือนครั้ง
# 3                  แทบไม่ได้บริโภคเลย           แทบไม่ได้บริโภคเลย
# 4                  แทบไม่ได้บริโภคเลย           แทบไม่ได้บริโภคเลย
#
#   บริโภค Content เกี่ยวกับการเมือง  \
# 0                        แทบทุกวัน
# 1                   อาทิตย์ละครั้ง
# 2                        แทบทุกวัน
# 3                เดือนละ 2-3 ครั้ง
# 4                เดือนละ 2-3 ครั้ง
#
#   นอกเหนือจากรายการดังกล่าวแล้ว คุณมีความสนใจในเรื่องใดอีกบ้าง  \
# 0                                   กีฬา UFC, Soccer
# 1                         กีฬา สัตว์เลี้ยง เทคโนโลยี
# 2                                                  -
# 3                                   โหราศาสตร์,ดูดวง
# 4                                        สัตว์เลี้ยง
#
#   คุณเกิดวันที่เท่าไหร่   เพศ อายุ
# 0   1988-09-19 00:00:00   ชาย   32
# 1   1993-08-10 00:00:00  หญิง   27
# 2   1993-11-07 00:00:00   ชาย   27
# 3   1994-04-14 00:00:00   ชาย   26
# 4   1995-04-19 00:00:00  หญิง   25
#
# [5 rows x 65 columns]

# %%
# Conveert Likert Scale
column_interest = [col for col in cust_df.columns if col.startswith('สนใจ')]
column_consume = [col for col in cust_df.columns if col.startswith('บริโภค')]

print(column_interest)
print(column_consume)
# Out:
# ['สนใจ อาหารญี่ปุ่น', 'สนใจ อาหารจึน', 'สนใจ อาหารไทย', 'สนใจ อาหารอีสาน', 'สนใจ อาหารสุขภาพ', 'สนใจ บุฟเฟต์', 'สนใจ ชาบูชาบู', 'สนใจ ปิ้งย่าง', 'สนใจ เหล้าเบียร์', 'สนใจ เสื้อผ้าแฟชั่น', 'สนใจ แต่งหน้า', 'สนใจ skincare บำรุงผิว', 'สนใจ การออกกำลังกาย', 'สนใจ การเล่นเกมส์', 'สนใจ การท่องเที่ยว', 'สนใจ การอ่านหนังสือ', 'สนใจ การอ่านบทความ Online', 'สนใจ การเรียน e-learning', 'สนใจ ดู Series', 'สนใจ ดูหนัง', 'สนใจ ดู Youtube', 'สนใจ ดู Netflix', 'สนใจ Content ด้านบันเทิง', 'สนใจ Content เกี่่ยวกับเกมส์', 'สนใจ Content เกี่ยวกับการ review ร้านอาหาร', 'สนใจ Content เกี่ยวกับการท่องเที่ยว', 'สนใจ Content เกี่ยวกับการแต่งบ้าน', 'สนใจ Content เกี่ยวกับการโทรทัศน์', 'สนใจ Content เกี่ยวกับละคร', 'สนใจ Content เกี่ยวกับการเมือง']
# ['บริโภค อาหารญี่ปุ่น', 'บริโภค อาหารจึน', 'บริโภค อาหารไทย', 'บริโภค อาหารอีสาน', 'บริโภค อาหารสุขภาพ', 'บริโภค บุฟเฟต์', 'บริโภค ชาบูชาบู', 'บริโภค ปิ้งย่าง', 'บริโภค เหล้าเบียร์', 'บริโภค เสื้อผ้าแฟชั่น', 'บริโภค แต่งหน้า', 'บริโภค skincare บำรุงผิว', 'บริโภค การออกกำลังกาย', 'บริโภค การเล่นเกมส์', 'บริโภค การท่องเที่ยว', 'บริโภค การอ่านหนังสือ', 'บริโภค การอ่านบทความ Online', 'บริโภค การเรียน e-learning', 'บริโภค ดู Series', 'บริโภค ดูหนัง', 'บริโภค ดู Youtube', 'บริโภค ดู Netflix', 'บริโภค Content ด้านบันเทิง', 'บริโภค Content เกี่่ยวกับเกมส์', 'บริโภค Content เกี่ยวกับการ review ร้านอาหาร', 'บริโภค Content เกี่ยวกับการท่องเที่ยว', 'บริโภค Content เกี่ยวกับการแต่งบ้าน', 'บริโภค Content เกี่ยวกับการโทรทัศน์', 'บริโภค Content เกี่ยวกับละคร', 'บริโภค Content เกี่ยวกับการเมือง']

# %%
# convert questionare to number
interest_to_numberic = {
    'ไม่สนใจอย่างมากที่สุด' : 1,
    'ไม่สนใจอย่างมาก' : 2,
    'ไม่สนใจ' : 3,
    'เฉยๆ' : 4,
    'สนใจ' : 5,
    'สนใจอย่างมาก' : 6,
    'สนใจอย่างมากที่สุด' : 7
}

consume_to_numberic = {
    'แทบไม่ได้บริโภคเลย' : 1,
    'หลายเดือนครั้ง' : 2,
    'เดือนละครั้ง' : 3,
    'เดือนละ 2-3 ครั้ง' : 4,
    'อาทิตย์ละครั้ง' : 5,
    'แทบทุกวัน' : 6,
}


cust_df[column_interest] = cust_df[column_interest].replace(interest_to_numberic)
cust_df[column_consume] = cust_df[column_consume].replace(consume_to_numberic)
cust_df.head()
# Out:
#                 Timestamp  สนใจ อาหารญี่ปุ่น  สนใจ อาหารจึน  สนใจ อาหารไทย  \
# 0 2021-01-09 10:07:27.365                  5              5              7
# 1 2021-01-09 10:07:34.010                  6              4              7
# 2 2021-01-09 10:07:35.902                  7              4              6
# 3 2021-01-09 10:07:36.476                  5              4              4
# 4 2021-01-09 10:07:41.965                  6              5              5
#
#    สนใจ อาหารอีสาน  สนใจ อาหารสุขภาพ  สนใจ บุฟเฟต์  สนใจ ชาบูชาบู  \
# 0                6                 5             5              5
# 1                6                 5             6              7
# 2                5                 4             7              7
# 3                4                 5             5              5
# 4                5                 7             4              4
#
#    สนใจ ปิ้งย่าง  สนใจ เหล้าเบียร์  ...  \
# 0              5                 7  ...
# 1              6                 3  ...
# 2              7                 2  ...
# 3              5                 1  ...
# 4              4                 4  ...
#
#    บริโภค Content เกี่ยวกับการ review ร้านอาหาร  \
# 0                                             4
# 1                                             6
# 2                                             6
# 3                                             3
# 4                                             3
#
#    บริโภค Content เกี่ยวกับการท่องเที่ยว  บริโภค Content เกี่ยวกับการแต่งบ้าน  \
# 0                                      4                                    4
# 1                                      6                                    5
# 2                                      4                                    4
# 3                                      3                                    1
# 4                                      4                                    3
#
#    บริโภค Content เกี่ยวกับการโทรทัศน์  บริโภค Content เกี่ยวกับละคร  \
# 0                                    4                             4
# 1                                    2                             2
# 2                                    4                             2
# 3                                    1                             1
# 4                                    1                             1
#
#    บริโภค Content เกี่ยวกับการเมือง  \
# 0                                 6
# 1                                 5
# 2                                 6
# 3                                 4
# 4                                 4
#
#    นอกเหนือจากรายการดังกล่าวแล้ว คุณมีความสนใจในเรื่องใดอีกบ้าง  \
# 0                                   กีฬา UFC, Soccer
# 1                         กีฬา สัตว์เลี้ยง เทคโนโลยี
# 2                                                  -
# 3                                   โหราศาสตร์,ดูดวง
# 4                                        สัตว์เลี้ยง
#
#    คุณเกิดวันที่เท่าไหร่   เพศ  อายุ
# 0    1988-09-19 00:00:00   ชาย    32
# 1    1993-08-10 00:00:00  หญิง    27
# 2    1993-11-07 00:00:00   ชาย    27
# 3    1994-04-14 00:00:00   ชาย    26
# 4    1995-04-19 00:00:00  หญิง    25
#
# [5 rows x 65 columns]

# %% [markdown]
# # Pearson Correlation

# %%
# หาคู่ขอข้อมูลที่มีค่า Correlation สัมพันธ์กันมากสุด
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=False)
    return au_corr[0:n]

print("Top 20 Correlations\n")
cor_df = cust_df[column_interest+column_consume]
print(get_top_abs_correlations(cor_df, 20))
# Out:
# Top 20 Correlations
#
# บริโภค Content เกี่ยวกับการโทรทัศน์  บริโภค Content เกี่ยวกับละคร           0.814394
# สนใจ การเล่นเกมส์                    สนใจ Content เกี่่ยวกับเกมส์           0.805294
# สนใจ แต่งหน้า                        บริโภค แต่งหน้า                        0.799858
# สนใจ Content ด้านบันเทิง             บริโภค Content ด้านบันเทิง             0.769667
# สนใจ การอ่านหนังสือ                  สนใจ การอ่านบทความ Online              0.764398
# สนใจ Content เกี่ยวกับการโทรทัศน์    สนใจ Content เกี่ยวกับละคร             0.764217
# สนใจ Content เกี่ยวกับการแต่งบ้าน    บริโภค Content เกี่ยวกับการแต่งบ้าน    0.755546
# สนใจ การเล่นเกมส์                    บริโภค การเล่นเกมส์                    0.749486
# สนใจ เหล้าเบียร์                     บริโภค เหล้าเบียร์                     0.749310
# บริโภค การเล่นเกมส์                  บริโภค Content เกี่่ยวกับเกมส์         0.747001
# สนใจ Content เกี่ยวกับการเมือง       บริโภค Content เกี่ยวกับการเมือง       0.744598
# สนใจ การเล่นเกมส์                    บริโภค Content เกี่่ยวกับเกมส์         0.741212
# สนใจ Content เกี่่ยวกับเกมส์         บริโภค Content เกี่่ยวกับเกมส์         0.738363
# สนใจ แต่งหน้า                        สนใจ skincare บำรุงผิว                 0.726883
# สนใจ Content ด้านบันเทิง             สนใจ Content เกี่ยวกับละคร             0.725700
# สนใจ บุฟเฟต์                         สนใจ ชาบูชาบู                          0.708651
# บริโภค ดู Series                     บริโภค ดู Netflix                      0.707700
# สนใจ อาหารสุขภาพ                     บริโภค อาหารสุขภาพ                     0.705114
# สนใจ ดู Series                       สนใจ ดู Netflix                        0.700209
# สนใจ อาหารอีสาน                      บริโภค อาหารอีสาน                      0.691658
# dtype: float64

# %%
# หาคู่ขอข้อมูลที่มีค่า Correlation สัมพันธ์กันน้อยสุด
def get_redundant_pairs(df):
    '''Get diagonal and lower triangular pairs of correlation matrix'''
    pairs_to_drop = set()
    cols = df.columns
    for i in range(0, df.shape[1]):
        for j in range(0, i+1):
            pairs_to_drop.add((cols[i], cols[j]))
    return pairs_to_drop

def get_top_abs_correlations(df, n=5):
    au_corr = df.corr().abs().unstack()
    labels_to_drop = get_redundant_pairs(df)
    au_corr = au_corr.drop(labels=labels_to_drop).sort_values(ascending=True)
    return au_corr[0:n]

print("Top 20 Least Correlations\n")
cor_df = cust_df[column_interest+column_consume]
print(get_top_abs_correlations(cor_df, 20))
# Out:
# Top 20 Least Correlations
#
# สนใจ การอ่านบทความ Online          บริโภค อาหารไทย                                 4.083232e-18
# สนใจ Content เกี่่ยวกับเกมส์       บริโภค การอ่านบทความ Online                     1.239546e-04
# สนใจ Content เกี่ยวกับละคร         บริโภค อาหารจึน                                 3.052987e-04
# บริโภค อาหารจึน                    บริโภค เหล้าเบียร์                              3.074464e-04
# สนใจ Content เกี่ยวกับการแต่งบ้าน  บริโภค อาหารญี่ปุ่น                             3.080929e-04
# บริโภค อาหารอีสาน                  บริโภค การอ่านบทความ Online                     3.826759e-04
# สนใจ การเรียน e-learning           บริโภค การท่องเที่ยว                            7.095661e-04
# สนใจ ดู Series                     บริโภค การอ่านบทความ Online                     7.708039e-04
# สนใจ Content เกี่่ยวกับเกมส์       บริโภค การท่องเที่ยว                            8.571678e-04
# สนใจ แต่งหน้า                      บริโภค อาหารจึน                                 1.068624e-03
# บริโภค การอ่านบทความ Online        บริโภค ดู Series                                1.103184e-03
# บริโภค ดูหนัง                      บริโภค Content เกี่ยวกับการ review ร้านอาหาร    1.175849e-03
# สนใจ บุฟเฟต์                       บริโภค Content เกี่ยวกับละคร                    1.185245e-03
# สนใจ การอ่านหนังสือ                บริโภค ดู Youtube                               1.225822e-03
# สนใจ อาหารจึน                      บริโภค Content เกี่ยวกับการแต่งบ้าน             1.238606e-03
# บริโภค แต่งหน้า                    บริโภค ดู Series                                1.251728e-03
# สนใจ อาหารญี่ปุ่น                  สนใจ แต่งหน้า                                   1.303307e-03
# สนใจ อาหารจึน                      บริโภค การอ่านหนังสือ                           1.373423e-03
# บริโภค อาหารสุขภาพ                 บริโภค Content เกี่ยวกับการเมือง                1.469315e-03
# สนใจ อาหารจึน                      สนใจ อาหารอีสาน                                 1.542436e-03
# dtype: float64

# %%
# draw with heatmap
cust_df.corr().style.background_gradient(cmap='Greens')
# Out:
# <style  type="text/css" >
# #T_3cbbb53e_867d_11eb_a873_acde48001122row0_col0,#T_3cbbb53e_867d_11eb_a873_acde48001122row1_col1,#T_3cbbb53e_867d_11eb_a873_acde48001122row2_col2,#T_3cbbb53e_867d_11eb_a873_acde48001122row3_col3,#T_3cbbb53e_867d_11eb_a873_acde48001122row4_col4,#T_3cbbb53e_867d_11eb_a873_acde48001122row5_col5,#T_3cbbb53e_867d_11eb_a873_acde48001122row6_col6,#T_3cbbb53e_867d_11eb_a873_acde48001122row7_col7,#T_3cbbb53e_867d_11eb_a873_acde48001122row8_col8,#T_3cbbb53e_867d_11eb_a873_acde48001122row9_col9,#T_3cbbb53e_867d_11eb_a873_acde48001122row10_col10,#T_3cbbb53e_867d_11eb_a873_acde48001122row11_col11,#T_3cbbb53e_867d_11eb_a873_acde48001122row12_col12,#T_3cbbb